# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataframe = pandas.read_csv('data.csv', usecols=[3], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 334 165

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 332/332 - 3s - loss: 0.1573 - 3s/epoch - 8ms/step
# Epoch 2/100
# 332/332 - 1s - loss: 0.0960 - 790ms/epoch - 2ms/step
# Epoch 3/100
# 332/332 - 1s - loss: 0.0916 - 799ms/epoch - 2ms/step
# Epoch 4/100
# 332/332 - 1s - loss: 0.0895 - 784ms/epoch - 2ms/step
# Epoch 5/100
# 332/332 - 1s - loss: 0.0885 - 773ms/epoch - 2ms/step
# Epoch 6/100
# 332/332 - 1s - loss: 0.0871 - 1s/epoch - 3ms/step
# Epoch 7/100
# 332/332 - 1s - loss: 0.0873 - 1s/epoch - 3ms/step
# Epoch 8/100
# 332/332 - 1s - loss: 0.0866 - 713ms/epoch - 2ms/step
# Epoch 9/100
# 332/332 - 1s - loss: 0.0866 - 820ms/epoch - 2ms/step
# Epoch 10/100
# 332/332 - 1s - loss: 0.0864 - 844ms/epoch - 3ms/step
# Epoch 11/100
# 332/332 - 1s - loss: 0.0867 - 1s/epoch - 3ms/step
# Epoch 12/100
# 332/332 - 1s - loss: 0.0867 - 912ms/epoch - 3ms/step
# Epoch 13/100
# 332/332 - 1s - loss: 0.0866 - 933ms/epoch - 3ms/step
# Epoch 14/100
# 332/332 - 1s - loss: 0.0863 - 628ms/epoch - 2ms/step
# Epoch 15/100
# 332/332 - 1s - loss: 0.0866 - 642ms/epoch - 2ms/step
# Epoch 16/100
# 332/332 - 1s - loss: 0.0862 - 969ms/epoch - 3ms/step
# Epoch 17/100
# 332/332 - 1s - loss: 0.0864 - 835ms/epoch - 3ms/step
# Epoch 18/100
# 332/332 - 1s - loss: 0.0865 - 763ms/epoch - 2ms/step
# Epoch 19/100
# 332/332 - 1s - loss: 0.0862 - 775ms/epoch - 2ms/step
# Epoch 20/100
# 332/332 - 1s - loss: 0.0862 - 806ms/epoch - 2ms/step
# Epoch 21/100
# 332/332 - 1s - loss: 0.0863 - 970ms/epoch - 3ms/step
# Epoch 22/100
# 332/332 - 1s - loss: 0.0862 - 769ms/epoch - 2ms/step
# Epoch 23/100
# 332/332 - 1s - loss: 0.0865 - 712ms/epoch - 2ms/step
# Epoch 24/100
# 332/332 - 1s - loss: 0.0864 - 926ms/epoch - 3ms/step
# Epoch 25/100
# 332/332 - 1s - loss: 0.0867 - 870ms/epoch - 3ms/step
# Epoch 26/100
# 332/332 - 1s - loss: 0.0862 - 578ms/epoch - 2ms/step
# Epoch 27/100
# 332/332 - 1s - loss: 0.0862 - 719ms/epoch - 2ms/step
# Epoch 28/100
# 332/332 - 1s - loss: 0.0868 - 821ms/epoch - 2ms/step
# Epoch 29/100
# 332/332 - 1s - loss: 0.0865 - 693ms/epoch - 2ms/step
# Epoch 30/100
# 332/332 - 1s - loss: 0.0863 - 573ms/epoch - 2ms/step
# Epoch 31/100
# 332/332 - 1s - loss: 0.0863 - 544ms/epoch - 2ms/step
# Epoch 32/100
# 332/332 - 1s - loss: 0.0863 - 620ms/epoch - 2ms/step
# Epoch 33/100
# 332/332 - 1s - loss: 0.0863 - 564ms/epoch - 2ms/step
# Epoch 34/100
# 332/332 - 1s - loss: 0.0863 - 557ms/epoch - 2ms/step
# Epoch 35/100
# 332/332 - 1s - loss: 0.0864 - 568ms/epoch - 2ms/step
# Epoch 36/100
# 332/332 - 1s - loss: 0.0866 - 577ms/epoch - 2ms/step
# Epoch 37/100
# 332/332 - 1s - loss: 0.0867 - 589ms/epoch - 2ms/step
# Epoch 38/100
# 332/332 - 1s - loss: 0.0865 - 568ms/epoch - 2ms/step
# Epoch 39/100
# 332/332 - 1s - loss: 0.0863 - 583ms/epoch - 2ms/step
# Epoch 40/100
# 332/332 - 1s - loss: 0.0864 - 538ms/epoch - 2ms/step
# Epoch 41/100
# 332/332 - 1s - loss: 0.0867 - 588ms/epoch - 2ms/step
# Epoch 42/100
# 332/332 - 1s - loss: 0.0865 - 672ms/epoch - 2ms/step
# Epoch 43/100
# 332/332 - 1s - loss: 0.0864 - 580ms/epoch - 2ms/step
# Epoch 44/100
# 332/332 - 1s - loss: 0.0865 - 603ms/epoch - 2ms/step
# Epoch 45/100
# 332/332 - 1s - loss: 0.0863 - 593ms/epoch - 2ms/step
# Epoch 46/100
# 332/332 - 1s - loss: 0.0862 - 585ms/epoch - 2ms/step
# Epoch 47/100
# 332/332 - 1s - loss: 0.0866 - 802ms/epoch - 2ms/step
# Epoch 48/100
# 332/332 - 1s - loss: 0.0866 - 632ms/epoch - 2ms/step
# Epoch 49/100
# 332/332 - 1s - loss: 0.0865 - 590ms/epoch - 2ms/step
# Epoch 50/100
# 332/332 - 1s - loss: 0.0863 - 567ms/epoch - 2ms/step
# Epoch 51/100
# 332/332 - 1s - loss: 0.0863 - 557ms/epoch - 2ms/step
# Epoch 52/100
# 332/332 - 1s - loss: 0.0862 - 661ms/epoch - 2ms/step
# Epoch 53/100
# 332/332 - 1s - loss: 0.0864 - 1s/epoch - 3ms/step
# Epoch 54/100
# 332/332 - 1s - loss: 0.0862 - 719ms/epoch - 2ms/step
# Epoch 55/100
# 332/332 - 1s - loss: 0.0865 - 589ms/epoch - 2ms/step
# Epoch 56/100
# 332/332 - 1s - loss: 0.0861 - 594ms/epoch - 2ms/step
# Epoch 57/100
# 332/332 - 1s - loss: 0.0865 - 579ms/epoch - 2ms/step
# Epoch 58/100
# 332/332 - 1s - loss: 0.0866 - 567ms/epoch - 2ms/step
# Epoch 59/100
# 332/332 - 1s - loss: 0.0864 - 1s/epoch - 3ms/step
# Epoch 60/100
# 332/332 - 1s - loss: 0.0862 - 736ms/epoch - 2ms/step
# Epoch 61/100
# 332/332 - 1s - loss: 0.0859 - 788ms/epoch - 2ms/step
# Epoch 62/100
# 332/332 - 1s - loss: 0.0865 - 1s/epoch - 3ms/step
# Epoch 63/100
# 332/332 - 1s - loss: 0.0861 - 1s/epoch - 4ms/step
# Epoch 64/100
# 332/332 - 1s - loss: 0.0863 - 1s/epoch - 3ms/step
# Epoch 65/100
# 332/332 - 1s - loss: 0.0865 - 1s/epoch - 3ms/step
# Epoch 66/100
# 332/332 - 1s - loss: 0.0864 - 1s/epoch - 3ms/step
# Epoch 67/100
# 332/332 - 1s - loss: 0.0864 - 908ms/epoch - 3ms/step
# Epoch 68/100
# 332/332 - 1s - loss: 0.0864 - 639ms/epoch - 2ms/step
# Epoch 69/100
# 332/332 - 1s - loss: 0.0867 - 582ms/epoch - 2ms/step
# Epoch 70/100
# 332/332 - 1s - loss: 0.0864 - 724ms/epoch - 2ms/step
# Epoch 71/100
# 332/332 - 1s - loss: 0.0864 - 564ms/epoch - 2ms/step
# Epoch 72/100
# 332/332 - 1s - loss: 0.0865 - 587ms/epoch - 2ms/step
# Epoch 73/100
# 332/332 - 1s - loss: 0.0863 - 598ms/epoch - 2ms/step
# Epoch 74/100
# 332/332 - 1s - loss: 0.0860 - 936ms/epoch - 3ms/step
# Epoch 75/100
# 332/332 - 1s - loss: 0.0861 - 809ms/epoch - 2ms/step
# Epoch 76/100
# 332/332 - 1s - loss: 0.0869 - 1s/epoch - 3ms/step
# Epoch 77/100
# 332/332 - 1s - loss: 0.0864 - 1s/epoch - 4ms/step
# Epoch 78/100
# 332/332 - 1s - loss: 0.0864 - 1s/epoch - 4ms/step
# Epoch 79/100
# 332/332 - 1s - loss: 0.0863 - 1s/epoch - 3ms/step
# Epoch 80/100
# 332/332 - 1s - loss: 0.0864 - 701ms/epoch - 2ms/step
# Epoch 81/100
# 332/332 - 1s - loss: 0.0866 - 704ms/epoch - 2ms/step
# Epoch 82/100
# 332/332 - 1s - loss: 0.0864 - 840ms/epoch - 3ms/step
# Epoch 83/100
# 332/332 - 1s - loss: 0.0863 - 780ms/epoch - 2ms/step
# Epoch 84/100
# 332/332 - 1s - loss: 0.0863 - 695ms/epoch - 2ms/step
# Epoch 85/100
# 332/332 - 1s - loss: 0.0862 - 663ms/epoch - 2ms/step
# Epoch 86/100
# 332/332 - 1s - loss: 0.0866 - 929ms/epoch - 3ms/step
# Epoch 87/100
# 332/332 - 1s - loss: 0.0865 - 1s/epoch - 4ms/step
# Epoch 88/100
# 332/332 - 1s - loss: 0.0864 - 980ms/epoch - 3ms/step
# Epoch 89/100
# 332/332 - 1s - loss: 0.0863 - 837ms/epoch - 3ms/step
# Epoch 90/100
# 332/332 - 1s - loss: 0.0862 - 990ms/epoch - 3ms/step
# Epoch 91/100
# 332/332 - 1s - loss: 0.0861 - 1s/epoch - 3ms/step
# Epoch 92/100
# 332/332 - 1s - loss: 0.0861 - 806ms/epoch - 2ms/step
# Epoch 93/100
# 332/332 - 1s - loss: 0.0865 - 732ms/epoch - 2ms/step
# Epoch 94/100
# 332/332 - 1s - loss: 0.0867 - 637ms/epoch - 2ms/step
# Epoch 95/100
# 332/332 - 1s - loss: 0.0865 - 810ms/epoch - 2ms/step
# Epoch 96/100
# 332/332 - 1s - loss: 0.0864 - 760ms/epoch - 2ms/step
# Epoch 97/100
# 332/332 - 1s - loss: 0.0866 - 734ms/epoch - 2ms/step
# Epoch 98/100
# 332/332 - 1s - loss: 0.0864 - 718ms/epoch - 2ms/step
# Epoch 99/100
# 332/332 - 1s - loss: 0.0863 - 734ms/epoch - 2ms/step
# Epoch 100/100
# 332/332 - 1s - loss: 0.0864 - 789ms/epoch - 2ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
print(trainScore)
print(testScore)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 11/11 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# 26.069088521308736
# 25.470119056399863

# %%
# Predictions RMSE are still too high, and predicted values tend to fluctuate around the median value without accounting for extreme values. 
# Further research needed....
